# %%
import matplotlib.pyplot as plt

# Collect F1 scores from each model using %run method
# %run decisionTree.ipynb
# %run gradientBoosterClassifier.ipynb
# %run logisticRegression.ipynb
# %run naiveBayesModel.ipynb
# %run randomForestClassifier.ipynb
# %run svmModel.ipynb

# Plotting
plt.figure(figsize=(12, 8))

# Collect F1 scores from each model
model_stats = {
    'Decision Tree': (decisionTreeF1Score1),
    'Gradient Booster': (gradientBoosterF1Score),
    'Logistic Regression': (logisticRegressionF1Score),
    'Naive Bayes': (naiveBayesF1Score),
    'Random Forest': (randomForestF1Score),
    'Support Vector Machine': (svmF1Score)
}

for i, (model, (F1Score)) in enumerate(model_stats.items()):
    plt.barh([model], F1Score, xerr=F1Score.std() * 2, alpha=0.6, label=model)

plt.xlabel('F1 Score')
plt.title('Comparison of Machine Learning Models')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Shape of Training and Testing Data for 20-22 Training Data
# (1183, 16)
# (1034, 16)
# Shape of Training and Testing Data for 21-22 Training Data
# (1183, 16)
# (1189, 16)
# Analysis for Decision Tree Model trained on the 2020-2021 and 2021-2022 Season Data
#
# 20-22 Decision Tree Model F1 Accuracy: 0.56 (+/- 0.19)
# Classification Report for Testing Data From the Training Split
#               precision    recall  f1-score   support
#
#            0       0.51      0.58      0.54       151
#            1       0.63      0.57      0.60       191
#
#     accuracy                           0.57       342
#    macro avg       0.57      0.57      0.57       342
# weighted avg       0.58      0.57      0.57       342
#
# Classification Report for Predictions on the 2022-2023 Season
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83       468
#            1       0.87      0.84      0.85       566
#
# ...
